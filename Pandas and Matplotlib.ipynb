# %% [markdown]
# # Assignment due Jan 15 - Pandas Introduction
# All questions are weighted the same in this assignment.
#
# ### For all questions write your own code and comments explaining what your code is doing.

# %% [markdown]
# <H2> Question 1</H2>
# A DataFrame is started below. Follow the instructions below to change the DataFrame. Make sure to include comments for your work.
# <ol>
#     <li>
# Add three more rows, for food items for Day 3,4,5 using append and .loc at least once each.
#     </li><li>
#     Add a column for Snack with different snacks for each day.
#       </li><li>
#      Add a column for Beverage with the same beverage for each day.>
#      </li><li> Query the DataFrame to get a list of all breakfast items.
#     </li><li> Query the DataFrame to get a list of just Snacks and Beverage for Day 2.
#         </li><li> Change the Breakfast item in Day 1 from 'Cereal' to 'Omelet'
#      </li><li> Drop a row from the DataFrame (not permanently removing it).
#     </li><li> Drop the 'Lunch' column from the DataFrame (permanently removing it).
#     </li><li> Update the DataFrame to  add  "and salad" to an appropriate column.
#     </li><ol>

# %%
import pandas as pd
dct1={'Breakfast':'Cereal','Lunch':'Sandwich','Supper':'Tacos'}
dct2={'Breakfast':'Eggs','Lunch':'Sandwich','Supper':'Hamburger'}
food_diary=pd.DataFrame([dct1,dct2],index=['Day 1','Day 2'])
food_diary
# Out:
#       Breakfast     Lunch     Supper
# Day 1    Cereal  Sandwich      Tacos
# Day 2      Eggs  Sandwich  Hamburger

# %%
#1 Add three more rows, for food items for Day 3,4,5 using append and .loc at least once each.

# create additional dataframes for days 3, 4, and 5
dct3 = {'Breakfast': 'Toast', 'Lunch': 'Pasta', 'Supper':'Sushi'}
dct4 = {'Breakfast': 'Rice Cake', 'Lunch': 'Rice', 'Supper':'Steak'}
#dct5 = {'Breakfast': 'Waffles', 'Lunch': 'Sandwich', 'Supper':'Ramen'}

# take the seperate dataframes and appened all them into a new df, called `food_345`
food_345 = pd.DataFrame([dct3, dct4], index = ['Day 3', 'Day 4'])

#creat row using loc
food_345.loc['Day 5'] = ['Waffles', 'Sandwich', 'Ramen']

# take the original dataframe, food_dairy, and append food_345 to it to create df
df = food_diary.append(food_345)
df
# Out:
#        Breakfast     Lunch     Supper
# Day 1     Cereal  Sandwich      Tacos
# Day 2       Eggs  Sandwich  Hamburger
# Day 3      Toast     Pasta      Sushi
# Day 4  Rice Cake      Rice      Steak
# Day 5    Waffles  Sandwich      Ramen

# %%
# 2 Add a column for Snack with different snacks for each day.

# create new column 'Snacks' and give it a list with 5 elements
df['Snacks']= ['Chips', 'Granola Bar', ' Apple', 'Orange', 'Beef Jerky']
df
# Out:
#        Breakfast     Lunch     Supper       Snacks
# Day 1     Cereal  Sandwich      Tacos        Chips
# Day 2       Eggs  Sandwich  Hamburger  Granola Bar
# Day 3      Toast     Pasta      Sushi        Apple
# Day 4  Rice Cake      Rice      Steak       Orange
# Day 5    Waffles  Sandwich      Ramen   Beef Jerky

# %%
# 3 Add a column for Beverage with the same beverage for each day.

# by giving 'Beverage' one one value, 'Lemonade', it populates all rows with the same value
df['Beverage'] = 'Lemonade'
df
# Out:
#        Breakfast     Lunch     Supper       Snacks  Beverage
# Day 1     Cereal  Sandwich      Tacos        Chips  Lemonade
# Day 2       Eggs  Sandwich  Hamburger  Granola Bar  Lemonade
# Day 3      Toast     Pasta      Sushi        Apple  Lemonade
# Day 4  Rice Cake      Rice      Steak       Orange  Lemonade
# Day 5    Waffles  Sandwich      Ramen   Beef Jerky  Lemonade

# %%
# 4 Query the DataFrame to get a list of all breakfast items.
df['Breakfast']
# Out:
# Day 1       Cereal
# Day 2         Eggs
# Day 3        Toast
# Day 4    Rice Cake
# Day 5      Waffles
# Name: Breakfast, dtype: object

# %%
# 5 Query the DataFrame to get a list of just Snacks and Beverage for Day 2.

# use `iloc` to show the specific location
df.iloc[1:2,3:5]
# Out:
#             Snacks  Beverage
# Day 2  Granola Bar  Lemonade

# %%
# 6 Change the Breakfast item in Day 1 from 'Cereal' to 'Omelet'

# use `iloc` to choose the location and then set equal to Omelet
df.iloc[0,0] = 'Omelet'
df
# Out:
#        Breakfast     Lunch     Supper       Snacks  Beverage
# Day 1     Omelet  Sandwich      Tacos        Chips  Lemonade
# Day 2       Eggs  Sandwich  Hamburger  Granola Bar  Lemonade
# Day 3      Toast     Pasta      Sushi        Apple  Lemonade
# Day 4  Rice Cake      Rice      Steak       Orange  Lemonade
# Day 5    Waffles  Sandwich      Ramen   Beef Jerky  Lemonade

# %%
# 7 Drop a row from the DataFrame (not permanently removing it).
df.drop('Day 3') #without inplace=True it will not permanently remove it
# Out:
#        Breakfast     Lunch     Supper       Snacks  Beverage
# Day 1     Omelet  Sandwich      Tacos        Chips  Lemonade
# Day 2       Eggs  Sandwich  Hamburger  Granola Bar  Lemonade
# Day 4  Rice Cake      Rice      Steak       Orange  Lemonade
# Day 5    Waffles  Sandwich      Ramen   Beef Jerky  Lemonade

# %%
# 8 Drop the 'Lunch' column from the DataFrame (permanently removing it).
df.drop('Lunch', axis = 1, inplace=True) #must use the axis variable to signify im dropping from columns
df
# Out:
#        Breakfast     Supper       Snacks  Beverage
# Day 1     Omelet      Tacos        Chips  Lemonade
# Day 2       Eggs  Hamburger  Granola Bar  Lemonade
# Day 3      Toast      Sushi        Apple  Lemonade
# Day 4  Rice Cake      Steak       Orange  Lemonade
# Day 5    Waffles      Ramen   Beef Jerky  Lemonade

# %%
# 9 Update the DataFrame to add "and salad" to an appropriate column.
df['Supper'] += ' and salad'
df
# Out:
#        Breakfast               Supper       Snacks  Beverage
# Day 1     Omelet      Tacos and salad        Chips  Lemonade
# Day 2       Eggs  Hamburger and salad  Granola Bar  Lemonade
# Day 3      Toast      Sushi and salad        Apple  Lemonade
# Day 4  Rice Cake      Steak and salad       Orange  Lemonade
# Day 5    Waffles      Ramen and salad   Beef Jerky  Lemonade

# %% [markdown]
# ## Question 2
#
# Create a DataFrame that records the number of hours you slept each day last week and the number of hours you studied each day last week. Index your DataFrame by ['Monday','Tuesday, etc]

# %%
day1={'Hours Slept':9,'Hours Studied':2}
day2={'Hours Slept':8, 'Hours Studied': 4}
day3={'Hours Slept':8, 'Hours Studied': 1}
day4={'Hours Slept':7, 'Hours Studied': 5}
day5={'Hours Slept':7, 'Hours Studied': 3}
day6={'Hours Slept':8, 'Hours Studied': 2}
day7={'Hours Slept':9, 'Hours Studied': 4}



# create dataframes of the Days and index over the day of the week
days_of_week = pd.DataFrame([day1,day2,day3,day4,day5,day6,day7],index=['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday'])
days_of_week
# Out:
#            Hours Slept  Hours Studied
# Monday               9              2
# Tuesday              8              4
# Wednesday            8              1
# Thursday             7              5
# Friday               7              3
# Saturday             8              2
# Sunday               9              4

# %% [markdown]
# ## Question 3
#
# Create a scatter plot for number of hours of sleep (x-axis) versus the number of hours of studying (y-axis).

# %%
import matplotlib.pyplot as plt
x = days_of_week["Hours Slept"] #use the values in Hours slept column for x 
y = days_of_week["Hours Studied"] #use the values in hours studied column for y
# can apply labels to x and y axis
plt.xlabel("Hours Slept")
plt.ylabel("Hours Studied")
# create scatter
plt.scatter(x, y, color = 'purple', marker = 's') # was messing around with color and markers

# %% [markdown]
# ## Question 4
#
# Create a bar plot for number of hours of studying last week

# %%
import numpy as np

#used example code found in the resources for barplots in matplotlib
height = days_of_week["Hours Studied"] #use values in column hours studied 
bars = list(days_of_week.index) #the bars will be the days of the week
y_pos = np.arange(len(bars)) #use numpy to make the y poistion be equal to the length of the bars from index
 
# Create bars
plt.bar(y_pos, height, color = 'cyan')
 
# Create names on the x-axis
plt.xticks(y_pos, bars)
plt.show()

# %% [markdown]
# ## Part 2
# The following code loads the olympics dataset (olympics.csv), which was derrived from the Wikipedia entry on [All Time Olympic Games Medals](https://en.wikipedia.org/wiki/All-time_Olympic_Games_medal_table), and does some basic data cleaning.
#
# The columns are organized as # of Summer games, Summer medals, # of Winter games, Winter medals, total # number of games, total # of medals. Use this dataset to answer the questions below.

# %%
url='http://facweb1.redlands.edu/fac/Tamara_Veenstra/ML/olympics.csv'
df = pd.read_csv(url, index_col=0, skiprows=1)

for col in df.columns:
    if col[:2]=='01':
        df.rename(columns={col:'Gold'+col[4:]}, inplace=True)
    if col[:2]=='02':
        df.rename(columns={col:'Silver'+col[4:]}, inplace=True)
    if col[:2]=='03':
        df.rename(columns={col:'Bronze'+col[4:]}, inplace=True)
    if col[:1]=='№':
        df.rename(columns={col:'#'+col[1:]}, inplace=True)
        
df.drop('Totals', inplace=True)

df.head(10)
# Out:
#                            # Summer  Gold  Silver  Bronze  Total  # Winter  \
# Afghanistan (AFG)                13     0       0       2      2         0
# Algeria (ALG)                    12     5       2       8     15         3
# Argentina (ARG)                  23    18      24      28     70        18
# Armenia (ARM)                     5     1       2       9     12         6
# Australasia (ANZ) [ANZ]           2     3       4       5     12         0
# Australia (AUS) [AUS] [Z]        25   139     152     177    468        18
# Austria (AUT)                    26    18      33      35     86        22
# Azerbaijan (AZE)                  5     6       5      15     26         5
# Bahamas (BAH)                    15     5       2       5     12         0
# Bahrain (BRN)                     8     0       0       1      1         0
#
#                            Gold.1  Silver.1  Bronze.1  Total.1  # Games  \
# ...

# %% [markdown]
# ## Question 5
#
# Explain what the line  "df.drop('Totals', inplace=True)" is doing in above data pre-processing.

# %% [markdown]
# The above code, `df.drop('Totals', inplace=True)` will permanently remove a row called "Totals" which probably appears as the last row in the dataframe.

# %% [markdown]
# ## Question 6
#
# Create a DataFrame for countries that have won no gold medals (winter or summer) but have won a silver medal (in either summer or winter).  How many such countries are there?

# %%
mask1 = df['Gold'] == 0
mask2 = df['Gold.1'] == 0
mask3 = df['Silver'] > 0
mask4 = df['Silver.1'] > 0
mask = (mask1 & mask2) & (mask3 | mask4) #why have the first boolean be an &? mask1 | mask2??
only_silver = df.where(mask)
only_silver = only_silver[mask]
only_silver.head()
# Out:
#                          # Summer  Gold  Silver  Bronze  Total  # Winter  \
# Bohemia (BOH) [BOH] [Z]       3.0   0.0     1.0     3.0    4.0       0.0
# Botswana (BOT)                9.0   0.0     1.0     0.0    1.0       0.0
# Ivory Coast (CIV) [CIV]      12.0   0.0     1.0     0.0    1.0       0.0
# Cyprus (CYP)                  9.0   0.0     1.0     0.0    1.0      10.0
# Gabon (GAB)                   9.0   0.0     1.0     0.0    1.0       0.0
#
#                          Gold.1  Silver.1  Bronze.1  Total.1  # Games  Gold.2  \
# Bohemia (BOH) [BOH] [Z]     0.0       0.0       0.0      0.0      3.0     0.0
# Botswana (BOT)              0.0       0.0       0.0      0.0      9.0     0.0
# Ivory Coast (CIV) [CIV]     0.0       0.0       0.0      0.0     12.0     0.0
# Cyprus (CYP)                0.0       0.0       0.0      0.0     19.0     0.0
# Gabon (GAB)                 0.0       0.0       0.0      0.0      9.0     0.0
#
# ...

# %%
# print how many countries met the criteria above
len(only_silver)
# Out:
# 31

# %% [markdown]
# ## Question 7
#
# Sort the only_silver DataFrame by number of total silvers.
# <br>
# Then query the DataFrame to determine highest number of silver medals won by a country with no gold medals.
# <br>
# Then query the DataFrame to determine the country or countries in only_silver that have won the most silver medals.
# Hint: check the values for all countries in only_silver.index.

# %%
# Sort the only_silver DataFrame by number of total silvers. 

only_silver = only_silver.sort_values(by = ['Silver.2'], ascending = False) 
#ascending = False will put the highest values at the top of the data frame
only_silver.head()
# Out:
#                       # Summer  Gold  Silver  Bronze  Total  # Winter  Gold.1  \
# Namibia (NAM)              6.0   0.0     4.0     0.0    4.0       0.0     0.0
# Malaysia (MAS) [MAS]      12.0   0.0     3.0     3.0    6.0       0.0     0.0
# Puerto Rico (PUR)         17.0   0.0     2.0     6.0    8.0       6.0     0.0
# Moldova (MDA)              5.0   0.0     2.0     5.0    7.0       6.0     0.0
# Philippines (PHI)         20.0   0.0     2.0     7.0    9.0       4.0     0.0
#
#                       Silver.1  Bronze.1  Total.1  # Games  Gold.2  Silver.2  \
# Namibia (NAM)              0.0       0.0      0.0      6.0     0.0       4.0
# Malaysia (MAS) [MAS]       0.0       0.0      0.0     12.0     0.0       3.0
# Puerto Rico (PUR)          0.0       0.0      0.0     23.0     0.0       2.0
# Moldova (MDA)              0.0       0.0      0.0     11.0     0.0       2.0
# Philippines (PHI)          0.0       0.0      0.0     24.0     0.0       2.0
#
# ...

# %%
#query the DataFrame to determine highest number of silver medals won by a country with no gold medals. 

only_silver = only_silver['Gold.2'] == 0 #create mask for no gold medals
only_silver = df.where(only_silver)

#high_silver = no_gold_mask.sort_values(by = ['Silver.2'], ascending = False) 

only_silver.loc[only_silver['Silver.2'].idxmax()] #Namibia has the most silver medals with no gold medals
# Out:
# # Summer          6.0
# Gold              0.0
# Silver            4.0
# Bronze            0.0
# Total             4.0
# # Winter          0.0
# Gold.1            0.0
# Silver.1          0.0
# Bronze.1          0.0
# Total.1           0.0
# # Games           6.0
# Gold.2            0.0
# Silver.2          4.0
# Bronze.2          0.0
# Combined total    4.0
# Name: Namibia (NAM), dtype: float64

# %%
df.sort_values(by = ['Silver.2'], ascending = False)
# Out:
#                                      # Summer  Gold  Silver  Bronze  Total  \
# United States (USA) [P] [Q] [R] [Z]        26   976     757     666   2399
# Soviet Union (URS) [URS]                    9   395     319     296   1010
# Great Britain (GBR) [GBR] [Z]              27   236     272     272    780
# Germany (GER) [GER] [Z]                    15   174     182     217    573
# France (FRA) [O] [P] [Z]                   27   202     223     246    671
# ...                                       ...   ...     ...     ...    ...
# Suriname (SUR) [E]                         11     1       0       1      2
# Djibouti (DJI) [B]                          7     0       0       1      1
# Burundi (BDI)                               5     1       0       0      1
# Iraq (IRQ)                                 13     0       0       1      1
# Afghanistan (AFG)                          13     0       0       2      2
#
# ...

# %% [markdown]
# ## Question 8
#
# Add a column to the DataFrame df that contains the value of summer gold medals - winter gold metals.
# Sort the DataFrame by this column and determine which country has the smallest value here and which has the largest value.

# %%
df['Summer Gold - Winter Gold'] = df['Gold'] - df['Gold.1']
df.head()
# Out:
#                          # Summer  Gold  Silver  Bronze  Total  # Winter  \
# Afghanistan (AFG)              13     0       0       2      2         0
# Algeria (ALG)                  12     5       2       8     15         3
# Argentina (ARG)                23    18      24      28     70        18
# Armenia (ARM)                   5     1       2       9     12         6
# Australasia (ANZ) [ANZ]         2     3       4       5     12         0
#
#                          Gold.1  Silver.1  Bronze.1  Total.1  # Games  Gold.2  \
# Afghanistan (AFG)             0         0         0        0       13       0
# Algeria (ALG)                 0         0         0        0       15       5
# Argentina (ARG)               0         0         0        0       41      18
# Armenia (ARM)                 0         0         0        0       11       1
# Australasia (ANZ) [ANZ]       0         0         0        0        2       3
#
# ...

# %% [markdown]
# ## Question 9
# Write a function that creates a Series called "Points" which is a weighted value where each gold medal (`Gold.2`) counts for 3 points, silver medals (`Silver.2`) for 2 points, and bronze medals (`Bronze.2`) for 1 point. The function should return only the column (a Series object) which you created, with the country names as indices.

# %%
def PointSeries(df):
    df["Gold.2"]*=3 # apply weight to gold
    goldNum = df['Gold.2'] 
    df['Silver.2']*=2 # apply weight to silver
    silverNum = df['Silver.2']
    df['Bronze.2'] # apply weight to bronze
    bronzeNum = df['Bronze.2']
    total_num = goldNum + silverNum + bronzeNum # create column and sum all the weights
    SeriesNum = pd.Series(total_num) # query the total weights
    Points = pd.Series(SeriesNum, index = df.index) 
    return Points
PointSeries(df)

#worked with John and Kimmy
# Out:
# Afghanistan (AFG)                                 2
# Algeria (ALG)                                    27
# Argentina (ARG)                                 130
# Armenia (ARM)                                    16
# Australasia (ANZ) [ANZ]                          22
#                                                ...
# Yugoslavia (YUG) [YUG]                          171
# Independent Olympic Participants (IOP) [IOP]      4
# Zambia (ZAM) [ZAM]                                3
# Zimbabwe (ZIM) [ZIM]                             18
# Mixed team (ZZX) [ZZX]                           38
# Length: 146, dtype: int64

# %% [markdown]
# ## Question 10
#
# How comfortable are you with pandas DataFrames after this homework assignment? Explain what you think you are understanding well and describe anything you would like to understand better.

# %% [markdown]
# I feel pretty good with pandas.  More complicated stuff such as the Olympic data was more challenging and it required me to reference the resources on Moodle but I eventually got the problems done.  However, going through examples similar to number 9 would be helpful because I probably wouldnt have gotten it without working with other students.  In general, the main difficulties is learning the syntax and writing the code rather than the process.
